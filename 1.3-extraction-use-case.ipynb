# %%
import os
# loading from a .env file
# load_dotenv(dotenv_path="/full/path/to/your/.env")

# or
# if you're on google colab just uncomment below and replace with your openai api key
# os.environ["OPENAI_API_KEY"] = "<your-openai-api-key>"
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Extracting data from legal documents
# Extracting data from scientific papers

# %% [markdown]
# # Extracting Product Information

# %%
# Extraction of customer feedback
from openai import OpenAI
from pydantic import BaseModel, Field

client = OpenAI()

class Product(BaseModel):
    name: str = Field(description="The name of the product")
    price: float = Field(description="The price of the product")
    description: str = Field(description="The description of the product if available in the raw data, if not available return 'N/A'")

def extract_product_info(product_raw_data: str) -> str:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are an expert at extracting\
                product information from raw data."},
            {"role": "user", "content": product_raw_data}
        ],
        response_format=Product
    )
    return response.choices[0].message.parsed

# %%
raw_data = """
Page 1
Voyager
Moonlander
Halfmoon
Ergodox EZ
ZSA

1
Cart

Learn More
Tools
Accessories
Checkout
“At this point I would find it hard to live without my current layout on the Moonlander, especially for my day-to-day work.”
- Jay Peters,

Introducing Moonlander Mark I
A next-generation ergonomic keyboard
In Stock. Ships in two weeks.
Work comfortably, for years to come.
There's no other keyboard quite like it.
Portable: carrying case included.

Modular: Remove or swap any part.

Fully backlit: RGB LEDs with smart animations.

Mechanical: Good old-fashioned keyswitches.

Gamer-friendly: Left side can fly solo.

Built to last: Two-year warranty. No fine print.

See it
“I’ve spent a lot of time with many ergonomic keyboards, but ZSA’s Moonlander Mark I may be my favorite one I’ve ever used”

- Jay Peters,
Read the full review
Used byDevelopers|
We make keyboards for pros. Five key questions, answered by our users.

Read user stories
See What People Say
Celebrating 40,000 Moonlanders
See them all
Two Halves
Place each half exactly where you need it. Typing at shoulder width keeps your chest open, which leads to a more relaxed posture.

No more hunching over the keyboard.

“I’ve come to really appreciate the split design of the keyboard. Whilst it felt faintly ridiculous at first to stand there with two halves shoulder-width apart like I was flying the USS Enterprise or something, I actually find it now a genuine delight to use.”
- Ben Frain
Comes from a great family
We've been making high-end keyboards since 2015. Here's our lineup.


Ultra-thin, compact, powerful.
Ultimate portability. Ergonomics, anywhere.
Learn More

Comfortable and modular.
Features an articulating thumb cluster. Over 40,000 units sold.
Customize yours

A time-tested classic.
Our first keyboard, going strong for years. An ergonomic classic with a big community.
Learn More

A macro pad for creatives.
For people who mainly use a keyboard as a control surface for a creative application.
Learn More
Columnar
Because when you extend a finger, it doesn‘t go sideways.

Columnar keyboards like the ErgoDox EZ and the Moonlander make it easier to reach above and below the home row. Stretch less, type more.

Watch
Connor Etherington Moonlander User
“its just the speed and efficiency of everything you can get done, I mean, nothing else you can do this with”

Active left side
The Moonlander has its USB Type-C connector on the left side, so you can use that side on its own.

When it‘s time to get your game on, unplug the right side and give your mouse some room to roam. The left side acts as a powerful macro pad.

See it
The Platform
An optional tenting accessory like no other: All-metal, slides, locks, and folds in seconds.

The Platform’s sophisticated latching system allows you to quickly disengage it and stow it away, flat, along with the Moonlander in the Moonlander’s carrying case.

More about The Platform
Blank or printed
The Moonlander comes with high-quality keycaps made of doubleshot PBT plastic. You can get them either with letters ("printed"), or just lines for the light to shine through ("blank").

The printed keycaps are all the same profile so you can use them as-is or move them around for different non-QWERTY layouts.

The blank keycaps are sculpted, so each row has a different profile for added typing comfort.

When in doubt, go with the printed caps; they're easier to start with.

Mechanical
In a mechanical keyboard, each keypress is crisp and distinct. Different keyswitches offer a dramatically different typing feel.

When building out your new Moonlander, choose between ten different types of switches. If you're not sure which is right for you, we'll help you choose.

See the keyswitches
Want to dive deeper into the world of keyswitches? Listen to Tisha talk about switches!

Hot-swappable
Change any keyswitch on your Moonlander at any time, without soldering and without voiding your warranty. Every unit ships with a free tool that makes this easy.

Your keyboard, your switches, your way.

Change it yourself
Fully backlit for
Photoshop
Writing
The Moonlander is fully backlit, with programmable RGB LEDs under each key.

Use them to light up the active keys on your current layer, remember shortcuts, and more.

“It is a dream come true. Each key in each layer is customizable to your exact specifications. So you can turn your keyboard into a light show for your entire neighbourhood to admire.”
- Stuart Hahn
Switch to Photoshop, and the "Photoshop" layer on your ZSA keyboard automatically activates. Click into Fortnite, and now your "Game" layer is suddenly active.

See Smart Layers
Lots of other powerful firmware features ↓
Lots of LED animations
While the Moonlander excels at the ergonomics of productivity, it also knows how to party. For those of you who enjoy watching LEDs dance, we made a little video showcasing some of the Mooonlander’s moves.

Party Time
Blinks and beeps
on command
The Moonlander comes with three status LEDs on each side and a buzzer for audio output. Get visual and audible feedback as you work, or not (you choose).

USB Type-C
The Moonlander comes with a detachable USB Type-C cable as well as a C-to-A dongle in the box.

Slim
The Moonlander‘s keycaps float on top of the board, for an exposed, clean look. It‘s one of the thinnest mechanical keyboards out there.

Folds for transport
When it‘s time to go, just fold the Wing under the Moonlander. It‘ll magnetically click into its stowed position.

Carrying case included
Every Moonlander comes with a Neoprene carrying case designed for safe transport in the smallest form factor possible.

Fold the case up, or put it flat into your backpack.

Learn by doing
It's deliberate practice, for typing. Our Live Training tool includes everything you need to master your new keyboard layout and level up over time, for your own comfort and productivity nirvana.

Learn by playing
Epistory: Typing Chronicles is an awesome game that will make you a better typist without you even noticing. Every Moonlander sold comes with a free, full license for Epistory.

See the game
Modules that work
together
The thumb module tilts up and down. Use it to find the perfect typing angle, and the wrist support module will automatically follow.

That’s a very smooth touchdown.

Thumb module
For small hands, tilt the thumb module up. For bigger hands, tilt it down.

A custom fit for your hand size.

The Launch and Any keys
You‘ll never have to hunt for these. Use them for things you do several times a day and that usually take multiple keypresses.

Switch your input locale or launch your password manager with a single tap of your index finger.

The piano keys
We designed these three easy-to-reach keys exclusively for the Moonlander, with a vertical profile and a dedicated backlight slot on each key.

Wrist support module
Also known as the Wing, this is a comfy landing spot for your palm.

It automatically angles when you tent and tilt the keyboard, so it‘ll always be where you expect it.

Prefer typing without wrist support? The module is easy to detach, no tools needed.

Optional Modules
The Moonlander has a rich array of optional accessories.
Zip Kit
Tripod Kit
The Platform
Community Creations
Shrink down your Moonlander.Learn about the Zip Kit.

Suspend your Moonlander in space. Use a tripod to attach the board anywhere and adjust it to any angle.Learn more about the Tripod Kit.

A tenting system like no other.Learn more about The Platform.

A selection of 3D printable accessories made by the ZSA community. Make the board your own.Community Creations.

"Too many keys? No problem, you can remove the ones you don't need. Is your thumb too strong and you keep accidentally hitting a particular key? Take its switch out and replace it with a stiffer switch. Key caps not to your liking? No worries; the keyboard uses MX-style switches, meaning you have an entire world of custom keycaps available to you. Want to tent it? Want to use inverse tilt? Want to use tripod-style mounting gear? All perfectly valid options."
- Aaron Harpole
It fits you
No matter what size hands you have, the Moonlander's Thumb and Wing modules can be adjusted to accommodate you perfectly.

Download a life-size printable PDF, to try it out on your desk


Small Hands
The thumb module articulates up, pulling the keys closer.

Average
The thumb and Wing modules allow for a relaxed neutral position.

Large Hands
The thumb module articulates down, letting your hand spread out while being supported by the Wing.
“The real distinguishing feature of the Moonlander is that it can tent up in the middle, which just rotates your hands out a little bit when you’re using it. And that’s a really big deal, immediately you can feel that is so much more comfortable.”
- Ben Vallack
Comes in two colors
Powered by a Cortex-M4
The powerful ARM processor built into the Moonlander drives fluid LED animations and other demanding firmware features without breaking a sweat.

Feline-approved
Click for cats
A fully-customizable typing experience

Make your keyboard work just like you want it

You don't have to code to customize the Moonlander. Oryx is a free, simple, and powerful keyboard layout editor. Point-and-click your way to the ultimate in comfort and productivity.

Remap any key

Don't like where something is? Move it. All keys can be remapped and reassigned, and most people iterate over their layouts until they're just right.


Tap for A, hold for Ctrl

One key can do two, three, or even four things. Tap-dance and dual-function keys make it easy to hold a key for Ctrl (for example) and tap it to get the letter “A”. All the power you need, within easy reach.


One-touch shortcuts

Want to set up a single key to send Cmd+S? Easy peasy.


Works with Mac, Linux, and Windows

All the “smarts” live on the board. No software or drivers required.


Unlock the power of system-wide hotkeys

Hyper is Ctrl+Shift+Alt+Win/Cmd, while Meh is Ctrl+Shift+Alt. No sane application on your machine uses these, which means you get free system-wide shortcuts.

Space-cadet Shift

Use your Shift key for more. Press and hold it, and it acts as Shift. Tap it on its own, and it sends parentheses — open parens on the Left Shift, close parens on the Right Shift.

This feature not enabled by default but is trivial to enable using Oryx.


Use multiple layers

With up to 32 layers, you can make a layer dedicated to your favorite game or app and get single-key access to helpful combos and shortcuts.

Alice was bengibb|
Master your layout easily with Live Training

Using just your browser (no need to download anything), Live Training allows you to practice your custom layout until it becomes second nature.


Visualize your layout

Oryx's Live View allows you to see what every key does, in every layer. Switch a layer, and the keymap on your screen updates in real time. This dynamic legend represents your keyboard without you ever having to look down.


Open-source firmware

The powerful firmware that runs on the Moonlander is called QMK, and it’s open-source, available on GitHub.

While you can use our configurator to quickly put together a layout, having complete access to the firmware source code means you can dig as deep as you’d like.

A thriving community

With thousands of people using our keyboards for all sorts of interesting things, there is never a lack of layouts to learn from. Some people even create layout tours to explain things better.



There’s more: A galaxy of firmware features for you to explore and experiment with.

Made by people
you can trust

Makers of

We’ve been making high-end keyboards for years.
People seem to like them.

Uncompromising
2-year warranty
The Moonlander is a serious investment in your future well being, and our warranty policy reflects this. We proudly offer a two-year, no-BS, no fine-print warranty on our keyboards.


We also fully support the Right to Repair, and offer parts for all of our keyboards.

Buy now
Thank you for creating a newsletter I WANT to read, instead of an auto delete.
Joel Jackson
Subscribe to The Ergo, our monthly newsletter. Even people who aren’t into keyboards seem to love it. Great finds from all over the Web, and a nice coupon for new subscribers (10% off ZSA Cards, our card deck).

Email
Subscribe
Success!
One issue per month, unsubscribe anytime.
See it first
© 2024 ZSA Technology Labs, Inc.
Help
Returns
FAQ
Privacy
Warranty
ZSA Moonlander: Next-gen Ergonomics | zsa.io

Page 2
Voyager
Moonlander
Halfmoon
Ergodox EZ
ZSA

1
Cart

Learn More
Tools
Accessories
Get Your Moonlander Mark I
Customize your new Moonlander below
Start
In Stock. Ships in two weeks.
Color

Moonlit

white


Dark Matter

black

Keycaps

Printed

RGB Compatible


Blank

RGB Compatible

Keyswitches

Cherry MX brown

tactile


Cherry MX blue

clicky


Kailh box red

linear

More Switches
Filter
all
tactile
linear
clicky
Cherry MX brown

tactile

Selected
More info
Cherry MX red

linear

Pick
More info
Cherry MX silent red

linear

Pick
More info
Cherry MX blue

clicky

Pick
More info
Kailh bronze

clicky

Pick
More info
Kailh gold

clicky

Pick
More info
Kailh silver

linear

Pick
More info
Kailh copper

tactile

Pick
More info
Kailh box brown

tactile

Pick
More info
Kailh box red

linear

Pick
More info
Kailh box white

clicky

Pick
More info
Kailh box black

linear

Pick
More info
Add to Cart
USD $365
Shipping included

Add to Cart
USD $365
Shipping included
or get it for a friend!

Photo: Andreas Tacke. Read the profile.
Thank you for creating a newsletter I WANT to read, instead of an auto delete.
Joel Jackson
Subscribe to The Ergo, our monthly newsletter. Even people who arent into keyboards seem to love it. Great finds from all over the Web, and a nice coupon for new subscribers (10% off ZSA Cards, our card deck).

Email
Subscribe
Success!
One issue per month, unsubscribe anytime.
See it first
© 2024 ZSA Technology Labs, Inc.
Help
Returns
FAQ
Privacy
Warranty
Get Your Moonlander | zsa.io
"""

product_data = extract_product_info(raw_data)
print(product_data)
# Out:
# name='Moonlander Mark I' price=365.0 description='A next-generation ergonomic keyboard that is fully backlit, modular, and designed for comfort and efficiency with features like hot-swappable keys, customizable layouts, and an optional tenting system.'

# %%
from IPython.display import Markdown

# Create a formatted markdown string with product details
markdown_output = f"""
# {product_data.name}

**Price:** ${product_data.price:.2f}

## Description
{product_data.description}
"""

Markdown(markdown_output)
# Out:
# # Moonlander Mark I
#
# **Price:** $365.00
#
# ## Description
# A next-generation ergonomic keyboard that is fully backlit, modular, and designed for comfort and efficiency with features like hot-swappable keys, customizable layouts, and an optional tenting system.

# %% [markdown]
# # Extracting structured data from customer tickets to automate customer support

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# csv_filename = '/content/gdrive/MyDrive/Moti_Work/AI-ML/oreilly_courses/ChatGPT_API_and_LangChain/extracted_ticket_issues.csv'

# %%
import pandas as pd

csv_filename = '/content/gdrive/MyDrive/Moti_Work/AI-ML/oreilly_courses/ChatGPT_API_and_LangChain/extracted_ticket_issues.csv'
df = pd.read_csv(csv_filename)
df.head()
# Out:
#    customer_name                                  issue_description priority
# 0       Jane Doe  Customer was charged twice for the same transa...     High
# 1     John Smith  Customer unable to log into their account, fac...   Medium
# 2  Alice Johnson  Customer wants more information about product ...      Low
# 3      Bob Brown  Customer has not received the order yet, track...     High
# 4    Michael Lee  Customer wants to return a product and needs a...   Medium

# %%
os.getcwd()
# Out:
# '/content'

# %%
from pydantic import BaseModel
from typing import Literal

class IssueCategory(BaseModel):
    category: Literal[
        "Billing Issues",
        "Account Access Issues",
        "Product Information Requests",
        "Order Delays",
        "Return Assistance"
    ] = Field(description="The category of the issue")


def extract_issue_categories(all_issues: str) -> list[IssueCategory]:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": "You are an expert at extracting issue categories from customer issues."}, {"role": "user", "content": all_issues}],
        response_format=IssueCategory
    )
    return response.choices[0].message.parsed.category

issue_examples = df['issue_description'].tolist()
issue_example = issue_examples[0]
issue_categories = extract_issue_categories(issue_example)
print(issue_categories)
# Out:
# Billing Issues

# %%
issue_example
# Out:
# 'Customer was charged twice for the same transaction.'

# %%
# Extract categories for all issues
all_categories = []
for issue in df['issue_description']:
    category = extract_issue_categories(issue)
    # Take first category if multiple are returned
    all_categories.append(category)

# Add new column with categories
df['issue_category'] = all_categories

# Display updated dataframe
print("\nDataframe with categorized issues:")
df.head()
# Out:
# Dataframe with categorized issues:
#    customer_name                                  issue_description priority  \
# 0       Jane Doe  Customer was charged twice for the same transa...     High
# 1     John Smith  Customer unable to log into their account, fac...   Medium
# 2  Alice Johnson  Customer wants more information about product ...      Low
# 3      Bob Brown  Customer has not received the order yet, track...     High
# 4    Michael Lee  Customer wants to return a product and needs a...   Medium
#
#                  issue_category
# 0                Billing Issues
# 1         Account Access Issues
# 2  Product Information Requests
# 3                  Order Delays
# 4             Return Assistance

# %%
# Create synthetic product review dataset
import pandas as pd
import numpy as np

# Sample data
products = ['Laptop Pro X', 'Wireless Earbuds', 'Smart Watch', 'Coffee Maker', 'Gaming Mouse']
ratings = [1, 2, 3, 4, 5]
review_texts = [
    "This laptop is amazing! The battery life exceeds expectations and the display is crystal clear.",
    "Decent sound quality but the battery drains too quickly. Could be better for the price.",
    "Perfect fitness companion. Tracks all my activities accurately and looks stylish.",
    "Makes great coffee but the warming plate stopped working after 3 months.",
    "Very responsive and comfortable for long gaming sessions. The RGB lighting is a nice touch.",
    "Keyboard started having issues after 6 months. Customer service was unhelpful.",
    "Best earbuds I've ever owned! The noise cancellation is outstanding.",
    "The screen is too dim for outdoor use. Otherwise works as advertised.",
    "Great value for money. Does everything I need it to do.",
    "Build quality could be better. Feels a bit cheap for the premium price."
]

# Create dataframe
reviews_df = pd.DataFrame({
    'product_name': np.random.choice(products, 10),
    'rating': np.random.choice(ratings, 10),
    'review_text': review_texts,
    'review_date': pd.date_range(start='2023-01-01', periods=10)
})

# Display the dataframe
print("Product Reviews Dataset:")
reviews_df
# Out:
# Product Reviews Dataset:
#        product_name  rating  \
# 0  Wireless Earbuds       5
# 1  Wireless Earbuds       1
# 2      Gaming Mouse       2
# 3       Smart Watch       2
# 4      Gaming Mouse       5
# 5      Coffee Maker       2
# 6       Smart Watch       5
# 7  Wireless Earbuds       1
# 8      Laptop Pro X       3
# 9  Wireless Earbuds       4
#
#                                          review_text review_date
# 0  This laptop is amazing! The battery life excee...  2023-01-01
# 1  Decent sound quality but the battery drains to...  2023-01-02
# 2  Perfect fitness companion. Tracks all my activ...  2023-01-03
# 3  Makes great coffee but the warming plate stopp...  2023-01-04
# 4  Very responsive and comfortable for long gamin...  2023-01-05
# 5  Keyboard started having issues after 6 months....  2023-01-06
# 6  Best earbuds I've ever owned! The noise cancel...  2023-01-07
# 7  The screen is too dim for outdoor use. Otherwi...  2023-01-08
# ...

# %%
class SentimentReview(BaseModel):
    sentiment: Literal["positive", "negative"] = Field(description="The sentiment of the review")

def extract_sentiment(review_text: str) -> SentimentReview:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": "You are an expert at extracting\
            sentiment from product reviews."}, {"role": "user", "content": review_text}],
        response_format=SentimentReview
    )
    return response.choices[0].message.parsed

# Extract sentiment for all reviews
all_sentiments = []
for review in reviews_df['review_text']:
    sentiment = extract_sentiment(review)
    all_sentiments.append(sentiment.sentiment)

# Add new column with sentiments
reviews_df['sentiment'] = all_sentiments

# Display updated dataframe
print("\nProduct Reviews Dataset with Sentiments:")
reviews_df
# Out:
# Product Reviews Dataset with Sentiments:
#        product_name  rating  \
# 0  Wireless Earbuds       5
# 1  Wireless Earbuds       1
# 2      Gaming Mouse       2
# 3       Smart Watch       2
# 4      Gaming Mouse       5
# 5      Coffee Maker       2
# 6       Smart Watch       5
# 7  Wireless Earbuds       1
# 8      Laptop Pro X       3
# 9  Wireless Earbuds       4
#
#                                          review_text review_date sentiment
# 0  This laptop is amazing! The battery life excee...  2023-01-01  positive
# 1  Decent sound quality but the battery drains to...  2023-01-02  negative
# 2  Perfect fitness companion. Tracks all my activ...  2023-01-03  positive
# 3  Makes great coffee but the warming plate stopp...  2023-01-04  negative
# 4  Very responsive and comfortable for long gamin...  2023-01-05  positive
# 5  Keyboard started having issues after 6 months....  2023-01-06  negative
# 6  Best earbuds I've ever owned! The noise cancel...  2023-01-07  positive
# ...

# %% [markdown]
# # Organizing your Files and Notes

# %%
# List all files in ./example-notes-files
# Create pydantic/openai data structure extraction for categorizing the types of files
# Run the categorization for all files and save the results to a dataframe with the original file name and its type

import os
file_locations = '/content/gdrive/MyDrive/Moti_Work/AI-ML/oreilly_courses/ChatGPT_API_and_LangChain/example-notes-files'

files = os.listdir(file_locations)
print(files)
# Out:
# ['note1.txt', 'note2.txt', 'paper-pancakes.pdf']

# %%
! pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from pypdf import PdfReader

class FileCategory(BaseModel):
    file_category: str = Field(description="The category of the file")


def extract_file_types(file_contents: str) -> FileCategory:
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": "You are an expert at categorizing files and notes."}, {"role": "user", "content": file_contents}],
        response_format=FileCategory
    )
    return response.choices[0].message.parsed

def load_pdf_text(file_path):
    '''Loads text from a PDF file.'''
    # creating a pdf reader object
    reader = PdfReader(file_path)

    # extracting text from page
    text = "\n\n".join([page.extract_text() for page in reader.pages])

    return text

def load_file(file_name: str) -> str:
    """Loads .txt, .md, .pdf files"""
    if file_name.endswith('.txt'):
        return open(file_name, 'r').read()
    elif file_name.endswith('.md'):
        return open(file_name, 'r').read()
    elif file_name.endswith('.pdf'):
        return load_pdf_text(file_name)


all_file_categories = {"category": [], "file_name": []}
for file in files:
    file_path = f'{file_locations}/{file}'
    file_contents = load_file(file_path)
    file_category = extract_file_types(file_contents)
    all_file_categories["category"].append(file_category.file_category)
    all_file_categories["file_name"].append(file)

df = pd.DataFrame(all_file_categories)
df.head()
# Out:
#          category           file_name
# 0  Personal Notes           note1.txt
# 1        Invoices           note2.txt
# 2  Research Paper  paper-pancakes.pdf

# %%
import shutil

def create_directory(directory_name: str):
    os.makedirs(directory_name, exist_ok=True)

def organize_files_by_category(files: list, base_dir: str = f'{file_locations}'):
    """
    Organizes files into directories based on their categories.

    Args:
        files: List of filenames to organize
        base_dir: Base directory to create category folders in
    """
    # Create base directory
    create_directory(base_dir)

    # Process each file
    for file in files:
        # Get original file path and contents
        orig_path = f'{file_locations}/{file}'
        file_contents = load_file(orig_path)

        # Get category
        file_category = extract_file_types(file_contents)
        category_dir = os.path.join(base_dir, file_category.file_category)

        # Create category directory
        create_directory(category_dir)

        # Copy file to new location
        dest_path = os.path.join(category_dir, file)
        shutil.copy2(orig_path, dest_path)

    return base_dir

# Organize the files
organized_dir = organize_files_by_category(files)
print(f"Files organized in: {organized_dir}")
# Out:
# Files organized in: /content/gdrive/MyDrive/Moti_Work/AI-ML/oreilly_courses/ChatGPT_API_and_LangChain/example-notes-files
